# %% [markdown]
# # Big Mountain Resort

# %% [markdown]
# # Context
# Big Mountain Resort receives roughly 350,000 customers annually and utilizes a market-guided approach to pricing, charging a slight premium over average. We were asked to come up with alternative pricing models via utilization of any of the following parameters:
# 1) Increasing ticket pricing even higher based on facilities advantages unique to Big Mountain.
#
# 2) Cutting operational costs.

# %% [markdown]
# # Method and Market Size
# The data provided did not include detailed breakdowns of the pricing of the facilities, so we focused on the ticket pricing in the US resort market. Due to a 1:1 relation of weekday and weekend pricing we chose to take the more complete Weekend ticket pricing as the primary to represent the market (Fig. 1). PCA analysis indicated no clear pricing pattern state-to-state, so we can safely assume a nationwide market, this is in line with Big Mountain’s market-guided approach (Fig. 2).

# %% [markdown]
# # Fig 1:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Fig 2:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Facilities Controlling Market Pricing

# %% [markdown]
# Models indicate a total of eight facilities as price significant: vertical drop, snow making acreage, total number of chairs, number of fast Quads, number of runs, length of longest run, number of trams, and the size of the skiable terrain. Of these, Big Mountain Resort nears the top of the resorts in all features save for vertical  drop (Fig. 3).

# %% [markdown]
# # Fig 3:

# %% [markdown]
# ![image.png](attachment:image.png)![image-2.png](attachment:image-2.png)![image-3.png](attachment:image-3.png)![image-4.png](attachment:image-4.png)![image-5.png](attachment:image-5.png)![image-6.png](attachment:image-6.png)![image-7.png](attachment:image-7.png)![image-8.png](attachment:image-8.png)![image-9.png](attachment:image-9.png)![image-10.png](attachment:image-10.png)

# %% [markdown]
# Given Big Mountain's current pricing of 81.00 per ticket we could justify an increase to 95.87 based on the current facilities. This falls outside the model error range of $10.39, which indicates that the price improvement is sound. The assumption of the model is that ticket pricing as provided by the data is accurate given to what consumers will pay for a given facilitiy. It would not be possible to detect over or underpricing by competing resorts given our current model/data set.

# %% [markdown]
# # Additional Modeling

# %% [markdown]
# Given the weight of umber of fast Quads, number of runs, snow making acreage and vertical drop we constructed the following model scenarios. The first (Fig.4) demonstrating what would happen if Big Mountain were to close down a given number of runs.
#
# The second would have Big Mountain add a run, and increase the vertical drop by 150 feet, and install an additional chair lift. Resulting in a increased support for ticket price by 9.15, over the season, this could be expected to amount to 16,008,523.
#
# The third would take the prior scenario and add 2 additional acres of snow making. This scenario increases support for ticket price by 9.85 Over the season, this could be expected to amount to 17,241,477.
#
# Finally we ran a model indicating there was no difference in increasing the length of the runs.

# %% [markdown]
# # Fig. 4:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Recommendation

# %% [markdown]
# Scenarios 2 and 3 are the most useful for Big Mountain Resorts to consider. If there is greater concern for the operational overhead, then Scenario 2 should be implemented over 3 as 3 will require additional snow machines and upkeep. Closing one run, per scenario 1, would not impact the ticket pricing at all while opening another run with an increased vertical drop could lead to even futher increased ticket pricing--the additional chair will cost the business 1,540,000 in operations, with 0.88 per ticket going into development. This would result in a net revenue of 13,525,471.

# %% [markdown]
# # Additional Concerns

# %% [markdown]
# If available, data about the cost of facilities other than the chairs would be appreciated to further refine the models.
